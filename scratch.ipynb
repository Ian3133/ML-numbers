# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.preprocessing as StadardScaler
#%pip install --upgrade scikit-learn imbalanced-learn
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf

# %% [markdown]
#  mushroom data set

# %%
# Mushrooms data set
file_path = "data/agaricus-lepiota.data"
cols = ["cap-shape", "cap-surface", "cap-color", "bruises", "odor", "gill attachment", "gill spacing", "gill size", "gill color", "stalk surface above ring", "stalk surface below ring", "stalk color above", "stalk color below", "veil type", "veil color", "ring number", "ring type", "spore print color", "population", "habiat" ]
muhsrooms = pd.read_csv(file_path, names=cols)
muhsrooms.head()
# Out:
#       cap-shape cap-surface cap-color bruises odor gill attachment  \
# p x s         n           t         p       f    c               n
# e x s         y           t         a       f    c               b
#   b s         w           t         l       f    c               b
# p x y         w           t         p       f    c               n
# e x s         g           f         n       f    w               b
#
#       gill spacing gill size gill color stalk surface above ring  \
# p x s            k         e          e                        s
# e x s            k         e          c                        s
#   b s            n         e          c                        s
# p x y            n         e          e                        s
# e x s            k         t          e                        s
#
#       stalk surface below ring stalk color above stalk color below veil type  \
# p x s                        s                 w                 w         p
# ...

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(muhsrooms)

# Tokenize the dataset
tokenized_dataset = tokenizer.texts_to_sequences(muhsrooms)

# Print the tokenized dataset
#for instance in tokenized_dataset:
#    print(instance)

# %% [markdown]
# tutoral dataset

# %%
file_path = "data/magic04.data"
cols = ["f-height", "fWidth", "fsize", "fConc", "fconc1", "fAsym", "Fm3Long", "fM3Trans", "fAlpha", "fDist", "class"]
data = pd.read_csv(file_path, names=cols)
#data.head()
#turn into 1 and 0's
data["class"] = (data["class"] =='g').astype(int)
data.head()
# Out:
#    f-height    fWidth   fsize   fConc  fconc1     fAsym  Fm3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
#see how each of the col effect the data 
for label in cols[:-1]:
    plt.hist(data[data["class"] == 1 ][label], color="blue", label="gamma", alpha=.5, density=True)
    plt.hist(data[data["class"] == 0 ][label], color="red", label="hadron", alpha=.5, density=True)
    plt.title(label)
    plt.ylabel("prob")
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %%
train, valid, test = np.split(data.sample(frac=1), [int(.6*len(data)), int(.8*len(data))])

# %%
def scale_dataset(dataframe, oversample=False):
  X = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values

  #scaler = StadardScaler()
  X = StadardScaler.FunctionTransformer(X)

  if oversample:
    ros = RandomOverSampler()
    X, y = ros.fit_resample(X, y)

  data = np.hstack((X, np.reshape(y, (-1, 1))))

  return data, X, y

# %%
print(len(train[train["class"] == 1])) # G
print(len(train[train["class"] == 0])) # h
# Out:
# 7454
# 3958

# %%
train, X_train, y_train = scale_dataset(train, oversample=True)
valid, X_valid, y_valid = scale_dataset(valid, oversample=False)
test, X_test, y_test = scale_dataset(test, oversample=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 train, X_train, y_train = scale_dataset(train, oversample=True)
#       2 valid, X_valid, y_valid = scale_dataset(valid, oversample=False)
#       3 test, X_test, y_test = scale_dataset(test, oversample=False)
#
# Cell In[40], line 10, in scale_dataset(dataframe, oversample)
#       8 if oversample:
#       9   ros = RandomOverSampler()
# ---> 10   X, y = ros.fit_resample(X, y)
#      12 data = np.hstack((X, np.reshape(y, (-1, 1))))
#      14 return data, X, y
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\imblearn\base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
# ...

# %%
def plot_history(history):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
  ax1.plot(history.history['loss'], label='loss')
  ax1.plot(history.history['val_loss'], label='val_loss')
  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Binary crossentropy')
  ax1.grid(True)

  ax2.plot(history.history['accuracy'], label='accuracy')
  ax2.plot(history.history['val_accuracy'], label='val_accuracy')
  ax2.set_xlabel('Epoch')
  ax2.set_ylabel('Accuracy')
  ax2.grid(True)

  plt.show()
